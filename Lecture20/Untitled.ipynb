# %%
using QuadGK

# %%
integrand(x, n) = x*n * exp(-x)
# Out:
# integrand (generic function with 1 method)

# %%
n = 1
quadgk(integrand(x, n), 0, 1)
# Out:
# UndefVarError: `x` not defined in `Main`
# Suggestion: check for spelling errors or missing imports.
#
# Stacktrace:
#  [1] top-level scope
#    @ In[7]:2
